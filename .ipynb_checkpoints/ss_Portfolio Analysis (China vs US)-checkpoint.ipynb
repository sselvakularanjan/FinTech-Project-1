# %%
# Import Libraries and Dependencies 
import pandas as pd
import numpy as np 
import os
import json
from pathlib import Path
from datetime import datetime, timedelta
from tiingo import TiingoClient
import hvplot.pandas
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-36f32a0e6d39> in <module>
#       6 from pathlib import Path
#       7 from datetime import datetime, timedelta
# ----> 8 from tiingo import TiingoClient
#       9 import hvplot.pandas
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'tiingo'

# %%
# Bring Env Variables into Python/Store in Variable
tiingo = os.getenv('TIINGO_API_KEY')

# %%
# Create a Client to Connect to Tiingo
client = TiingoClient()

# %%
# Create Start and End Dates for 1 Year's Worth of Historical Data
end = datetime.now()
start = end + timedelta(-365)

# %% [markdown]
# # DataFrames for Stock Tickers

# %%
# Create DataFrames for China
china_ticker_df = client.get_dataframe(['ASHR','CQQQ', 'CHIE', 'CHIM', 'KURE', 'CHIS'],
                                            metric_name='close',
                                            startDate= start,
                                            endDate= end,
                                            frequency='daily')
china_ticker_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5ba590d1b177> in <module>
#       1 # Create DataFrames for China
# ----> 2 china_ticker_df = client.get_dataframe(['ASHR','CQQQ', 'CHIE', 'CHIM', 'KURE', 'CHIS'],
#       3                                             metric_name='close',
#       4                                             startDate= start,
#       5                                             endDate= end,
#
# NameError: name 'client' is not defined

# %%
china_df = china_ticker_df.rename(columns={'CQQQ':'CQQQ (Technology)', 'CHIE':'CHIE (Energy)', 'CHIM':'CHIM (Materials)', 'KURE':'KURE (Healthcare)', 'CHIS':'CHIS (Consumer Staples)'})
china_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-356fa306bfc0> in <module>
# ----> 1 china_df = china_ticker_df.rename(columns={'CQQQ':'CQQQ (Technology)', 'CHIE':'CHIE (Energy)', 'CHIM':'CHIM (Materials)', 'KURE':'KURE (Healthcare)', 'CHIS':'CHIS (Consumer Staples)'})
#       2 china_df.head()
#
# NameError: name 'china_ticker_df' is not defined

# %%
# Create DataFrames for China
us_ticker_df = client.get_dataframe(['SPY','IGM', 'IYE', 'IYM', 'IYH', 'IECS'],
                                            metric_name='close',
                                            startDate= start,
                                            endDate= end,
                                            frequency='daily')
us_ticker_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e157784c231f> in <module>
#       1 # Create DataFrames for China
# ----> 2 us_ticker_df = client.get_dataframe(['SPY','IGM', 'IYE', 'IYM', 'IYH', 'IECS'],
#       3                                             metric_name='close',
#       4                                             startDate= start,
#       5                                             endDate= end,
#
# NameError: name 'client' is not defined

# %%
us_df = us_ticker_df.rename(columns={'IGM':'IGM (Technology)', 'IYE':'IYE (Energy)', 'IYM':'IYM (Materials)', 'IYH':'IYH (Healthcare)', 'IECS':'IECS (Consumer Staples)'})
us_df.head()
# Out:
#                               SPY  IGM (Technology)  IYE (Energy)  \
# date
# 2019-02-06 00:00:00+00:00  272.74          193.7109         35.16
# 2019-02-07 00:00:00+00:00  270.14          190.7848         34.36
# 2019-02-08 00:00:00+00:00  270.47          191.5262         34.20
# 2019-02-11 00:00:00+00:00  270.62          191.8665         34.39
# 2019-02-12 00:00:00+00:00  274.10          194.7900         34.83
#
#                            IYM (Materials)  IYH (Healthcare)  \
# date
# 2019-02-06 00:00:00+00:00            89.50          191.0895
# 2019-02-07 00:00:00+00:00            87.83          189.0200
# 2019-02-08 00:00:00+00:00            87.58          189.2100
# 2019-02-11 00:00:00+00:00            87.92          189.1700
# 2019-02-12 00:00:00+00:00            89.89          191.6600
#
#                            IECS (Consumer Staples)
# date
# 2019-02-06 00:00:00+00:00                  24.5705
# 2019-02-07 00:00:00+00:00                  24.5157
# 2019-02-08 00:00:00+00:00                  24.6313
# 2019-02-11 00:00:00+00:00                  24.7325
# 2019-02-12 00:00:00+00:00                  24.9152

# %% [markdown]
# # Daily Returns for Stocks

# %%
# Calculate the Daily ROI for China Stocks
china_daily_returns = china_df.pct_change()
china_daily_returns.head()
# Out:
#                                ASHR  CQQQ (Technology)  CHIE (Energy)  \
# date
# 2019-02-06 00:00:00+00:00       NaN                NaN            NaN
# 2019-02-07 00:00:00+00:00 -0.009102          -0.025426      -0.014194
# 2019-02-08 00:00:00+00:00 -0.005846           0.013158      -0.006108
# 2019-02-11 00:00:00+00:00  0.026879           0.012315       0.009219
# 2019-02-12 00:00:00+00:00  0.008589           0.015262      -0.000435
#
#                            CHIM (Materials)  KURE (Healthcare)  \
# date
# 2019-02-06 00:00:00+00:00               NaN                NaN
# 2019-02-07 00:00:00+00:00         -0.010576          -0.005791
# 2019-02-08 00:00:00+00:00          0.008791          -0.012457
# 2019-02-11 00:00:00+00:00          0.003448           0.026405
# 2019-02-12 00:00:00+00:00         -0.000937           0.027132
#
#                            CHIS (Consumer Staples)
# date
# 2019-02-06 00:00:00+00:00                      NaN
# 2019-02-07 00:00:00+00:00                -0.005727
# 2019-02-08 00:00:00+00:00                -0.005233
# 2019-02-11 00:00:00+00:00                 0.018733
# 2019-02-12 00:00:00+00:00                 0.006197

# %%
# Calculate the Daily ROI for US Stocks
us_daily_returns = us_df.pct_change()
us_daily_returns.head()
# Out:
#                                 SPY  IGM (Technology)  IYE (Energy)  \
# date
# 2019-02-06 00:00:00+00:00       NaN               NaN           NaN
# 2019-02-07 00:00:00+00:00 -0.009533         -0.015106     -0.022753
# 2019-02-08 00:00:00+00:00  0.001222          0.003886     -0.004657
# 2019-02-11 00:00:00+00:00  0.000555          0.001777      0.005556
# 2019-02-12 00:00:00+00:00  0.012859          0.015237      0.012794
#
#                            IYM (Materials)  IYH (Healthcare)  \
# date
# 2019-02-06 00:00:00+00:00              NaN               NaN
# 2019-02-07 00:00:00+00:00        -0.018659         -0.010830
# 2019-02-08 00:00:00+00:00        -0.002846          0.001005
# 2019-02-11 00:00:00+00:00         0.003882         -0.000211
# 2019-02-12 00:00:00+00:00         0.022407          0.013163
#
#                            IECS (Consumer Staples)
# date
# 2019-02-06 00:00:00+00:00                      NaN
# 2019-02-07 00:00:00+00:00                -0.002230
# 2019-02-08 00:00:00+00:00                 0.004715
# 2019-02-11 00:00:00+00:00                 0.004109
# 2019-02-12 00:00:00+00:00                 0.007387

# %%
# Plot China Daily ROIs and US Daily ROIs
china_roi_plot= china_daily_returns.hvplot(label= '2019 - current')
us_roi_plot = us_daily_returns.hvplot(label= '2019 - current' )

china_roi_plot * us_roi_plot

# %% [markdown]
# # Daily Standard Deviations for Portfolios

# %%
# Calculate the Standard Deviation for China Portfolio
china_std = china_daily_returns.std()
china_std
# Out:
# ASHR                       0.015939
# CQQQ (Technology)          0.016293
# CHIE (Energy)              0.012746
# CHIM (Materials)           0.014438
# KURE (Healthcare)          0.016370
# CHIS (Consumer Staples)    0.013429
# dtype: float64

# %%
# Calculate the Standard Deviation for Portfolio 
us_std = us_daily_returns.std()
us_std
# Out:
# SPY                        0.007583
# IGM (Technology)           0.010378
# IYE (Energy)               0.012610
# IYM (Materials)            0.010357
# IYH (Healthcare)           0.008379
# IECS (Consumer Staples)    0.006289
# dtype: float64

# %%
# Annualized Standard Deviation (252 Trading Days) for China Portfolio
annualized_china_std = china_std * np.sqrt(252)
annualized_china_std
# Out:
# ASHR                       0.253031
# CQQQ (Technology)          0.258641
# CHIE (Energy)              0.202334
# CHIM (Materials)           0.229196
# KURE (Healthcare)          0.259869
# CHIS (Consumer Staples)    0.213181
# dtype: float64

# %%
# Annualized Standard Deviation (252 Trading Days) for US Portfolio
annualized_us_std = us_std * np.sqrt(252)
annualized_us_std
# Out:
# SPY                        0.120380
# IGM (Technology)           0.164750
# IYE (Energy)               0.200174
# IYM (Materials)            0.164418
# IYH (Healthcare)           0.133018
# IECS (Consumer Staples)    0.099831
# dtype: float64

# %% [markdown]
# # Rolling Statistics

# %%
# Calculate and Plot the Rolling Standard Deviation for China (using a 21 day window)
china_daily_returns.rolling(window=21).std().plot(figsize=(20,10), title='Rolling Statistics for China ~21 days')

# %%
# Calculate and Plot the Rolling Standard Deviation for US (using a 21 day window)
us_daily_returns.rolling(window=21).std().plot(figsize=(20,10), title='Rolling Statistics for US ~21 days')

# %% [markdown]
# # Correlation/Beta

# %%
# China's Correlation 
china_correlation = china_daily_returns.corr()
china_correlation

# If we need the heatmap:
## import seaborn as sns
## sns.heatmap(china_correlation, vmin=-1, vmax=1, annot=True)
# Out:
#                              ASHR  CQQQ (Technology)  CHIE (Energy)  \
# ASHR                     1.000000           0.798575       0.561571
# CQQQ (Technology)        0.798575           1.000000       0.519596
# CHIE (Energy)            0.561571           0.519596       1.000000
# CHIM (Materials)         0.784376           0.677360       0.553468
# KURE (Healthcare)        0.718025           0.660631       0.437183
# CHIS (Consumer Staples)  0.755021           0.715986       0.487351
#
#                          CHIM (Materials)  KURE (Healthcare)  \
# ASHR                             0.784376           0.718025
# CQQQ (Technology)                0.677360           0.660631
# CHIE (Energy)                    0.553468           0.437183
# CHIM (Materials)                 1.000000           0.557330
# KURE (Healthcare)                0.557330           1.000000
# CHIS (Consumer Staples)          0.629741           0.654645
#
#                          CHIS (Consumer Staples)
# ASHR                                    0.755021
# CQQQ (Technology)                       0.715986
# CHIE (Energy)                           0.487351
# CHIM (Materials)                        0.629741
# KURE (Healthcare)                       0.654645
# CHIS (Consumer Staples)                 1.000000

# %%
# Calculate Beta for China Portfolio 
china_covariance = china_daily_returns['CQQQ (Technology)'].cov(china_daily_returns['ASHR'])
china_variance = china_daily_returns['ASHR'].var()
china_beta = china_covariance / china_variance
china_beta
# Out:
# 0.8162792132247914

# %% [markdown]
# rolling_china_covariance = china_daily_returns['CQQQ (Technology)'].rolling(window=30).cov(china_daily_returns['ASHR'])
# rolling_china_covariance.plot(figsize=(20, 10))

# %%
# US's Correlation 
us_correlation = us_daily_returns.corr()
us_correlation

# If we need the heatmap:
## import seaborn as sns
## sns.heatmap(us_correlation, vmin=-1, vmax=1, annot=True)
# Out:
#                               SPY  IGM (Technology)  IYE (Energy)  \
# SPY                      1.000000          0.924682      0.659807
# IGM (Technology)         0.924682          1.000000      0.542759
# IYE (Energy)             0.659807          0.542759      1.000000
# IYM (Materials)          0.789535          0.661752      0.631927
# IYH (Healthcare)         0.773115          0.664280      0.463303
# IECS (Consumer Staples)  0.645377          0.509438      0.309981
#
#                          IYM (Materials)  IYH (Healthcare)  \
# SPY                             0.789535          0.773115
# IGM (Technology)                0.661752          0.664280
# IYE (Energy)                    0.631927          0.463303
# IYM (Materials)                 1.000000          0.564217
# IYH (Healthcare)                0.564217          1.000000
# IECS (Consumer Staples)         0.491616          0.547804
#
#                          IECS (Consumer Staples)
# SPY                                     0.645377
# IGM (Technology)                        0.509438
# IYE (Energy)                            0.309981
# IYM (Materials)                         0.491616
# IYH (Healthcare)                        0.547804
# IECS (Consumer Staples)                 1.000000

# %%
# Calculate Beta for US Portfolio 
us_covariance = us_daily_returns['IGM (Technology)'].cov(us_daily_returns['SPY'])
us_variance = us_daily_returns['SPY'].var()
us_beta = us_covariance / us_variance
us_beta
# Out:
# 1.2655039528018308

# %%
rolling_us_covariance = us_daily_returns['IGM (Technology)'].rolling(window=30).cov(us_daily_returns['SPY'])
rolling_us_covariance.plot(figsize=(20, 10))

# %% [markdown]
# # Sharpe Ratios for Portfolios

# %%
# Annualized Sharpe Ratios for China Portfolio
china_sharpe_ratios = (china_daily_returns.mean() * 252) / annualized_china_std
china_sharpe_ratios
# Out:
# ASHR                       0.652662
# CQQQ (Technology)          0.884866
# CHIE (Energy)             -0.761957
# CHIM (Materials)          -0.029178
# KURE (Healthcare)          1.145193
# CHIS (Consumer Staples)    1.274640
# dtype: float64

# %%
# Visualizing the Sharpe Ratio for China Portfolio
china_sharpe_ratios.plot.bar()

# %%
# Annualized Sharpe Ratios for US Portfolio
us_sharpe_ratios = (us_daily_returns.mean() * 252) / annualized_us_std
us_sharpe_ratios
# Out:
# SPY                        1.722204
# IGM (Technology)           1.894764
# IYE (Energy)              -0.819349
# IYM (Materials)            0.494902
# IYH (Healthcare)           1.118436
# IECS (Consumer Staples)    1.794626
# dtype: float64

# %%
# Visualizing the Sharpe Ratio for US Portfolio
us_sharpe_ratios.plot.bar()
